# %% [markdown]
# # Lecture09 - Recitation

# %% [markdown]
# # Analytical Problems

# %% [markdown]
# ## Exercise 1
#
# **Answer the following questions:**
#
# 1. **Network A has 10 identical and independent network devices connected in series. Let E be the event that data can pass through the network, which requires that all the network devices are operational. Let $A_i$ denote the event that the $i$th device fails, and $P(A_i) = P_A$, which does not depend on $i$. What value of $P_A$ is required to achieve $P(E) = 0.9$?**

# %% [markdown]
# 2. **Network B has 10 identical and independent network devices connected in parallel. Let F be the event that data can pass through the network, which will occur if any of the network devices are operational. Let $B_i$ denote the event that the $i$th
# device fails, and $P(B_i) = P_B$, which does not depend on $i$. What value of $P_B$ gives $P(F) = 0.9$?**

# %% [markdown]
# 3. **Network C has 10 identical and independent network devices. The network is designed so that data can pass through at one-half the full rate if either 2 or 3 network devices are operational. Let $H$ be the event that data can pass through the network at one-half the full rate. If the probability that a network device fails is $P_C = 0.8$, what is $P(H)$?**

# %% [markdown]
# ___

# %% [markdown]
# ## Exercise 2
#
# **A local telephone number is a 7-digit sequence, but the first digit has to be different from 0 or 1. How many distinct telephone numbers are there?**

# %% [markdown]
# ___

# %% [markdown]
# ## Exercise 3
#
# **Select 3 cards at random from a standard 52-card playing deck. What is the probability that these cards contain *at least* one ace?**

# %% [markdown]
# ___

# %% [markdown]
# ## Exercise 4
#
# **Ten passengers get on an airport shuttle at the airport. The shuttle has a route that includes 5 hotels, and each passenger gets off the shuttle at his/her hotel. The driver records how many passengers leave the shuttle at each hotel. How many different possibilities exist?**

# %% [markdown]
# ___

# %% [markdown]
# # Simulation Problems

# %% [markdown]
# ## Exercise 5
#
# **The Python code below is used to simulate a scenario involving coins, where the variable ```total_num``` is a positive integer.**
#
# **1. Describe the experiment being simulated.**
#
# **2. The code is printing a ratio that is an estimate of a probability. Write that probability in mathematical notation. Define the notation you use for any events.**

# %%
Image('figures/simulation.png',width=700)

# %% [markdown]
# ___

# %%
# Load libraries and magics for the rest of the exercises

# %% [markdown]
# ## Exercise 6
#
# **In what follows, apply a significance value $\alpha = 0.01$. That is, there must be less than a 1% probability of seeing such an extreme value under the null hypothesis before we are willing to conclude that the null hypothesis is not reasonable.**
#
# * **If a 6-sided die is rolled 12 times and all the values are <=4, should we feel confident that the die is not fair (i.e., reject the null hypothesis with $p=0.01$)?**
#
# * **Define the null hypothesis $H_0$ and the alternative hypothesis $H_1$.**
#
# * **Conduct the above simulation using a python function.**

# %% [markdown]
# ___

# %% [markdown]
# ## Exercise 7
#
# **A state has license plates of the form XXXX, where X can be any letter of the alphabet (A) or a numeric digit (D).**
#
# **Let's first define all possible outcomes of drawing an alphabetic character (26 letters):**

# %%
import string

A=list(string.ascii_lowercase) # This list contains all possible alphabetic characters
print(A)

# %% [markdown]
# **And then define all possible outcomes of drawing a numeric digit (10 numbers in the interval [0-9]):**

# %%
D=list(range(10)) # This list contains all possible digits
print(D)

# %% [markdown]
# **Using ```itertools```, compute the cardinality of the sample space of all the license plates of the form AAA DDDD.**

# %% [markdown]
# ___

# %% [markdown]
# ## Exercise 8
#
# **Using ```itertools```, create a list of all the three-number lock combinations, where the numbers are from 1 to 50 and can be repeated. How many are there?**

# %% [markdown]
# ___

# %% [markdown]
# ## Exercise 9
#
# **Consider the dataset in "firearms-combined.csv". Use ```pandas``` to answer the following questions:**
#
# 1. **Load the data.**
# 2. **Use [Boolean operators](https://jakevdp.github.io/PythonDataScienceHandbook/02.06-boolean-arrays-and-masks.html) to find the states with a 2005 firearms rate mortality in the interval $[8,15]$.**
# 3. **Create another dataframe whose index is sorted by the state.**
# 4. **Use a [dataframe indexer](https://jakevdp.github.io/PythonDataScienceHandbook/03.02-data-indexing-and-selection.html) (```iloc```, ```loc``` or ```ix```) to find Florida's numbers for all 3 columns.**
# 5. **Using dataframe indexing to create another dataframe that only contains index rows for which the mortality rate for 2014 is in the interval $[8,15]$.**

# %% [markdown]
# ___

# %% [markdown]
# ## Exercise 10
#
# **In this problem you will be using the dataset "firearms-combined.csv".**
#
# **Answer the following questions:**
# 1. **Create two dataframes, one for which the total number of gun laws in 2014 is greater or equal to 50 (call it L50), and another dataframe where it is less than 50 (call it G50).**
# 2. **Extract into numpy arrays the 2014 firearms mortality rate for L50 and G50.**
# 3. **Plot the data, compute summary statistics and design a binary hypothesis test.**
# 4. **Use the mean-difference statistic with a significance level of $\alpha=0.05$. Conduct a two-sided Bootstrap simulation to carry the hypothesis test. Draw conclusions.**
# 5. **Compute the 95% confidence interval. Draw conclusions.**

# %% [markdown]
# ___
